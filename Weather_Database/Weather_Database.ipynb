# %%
#Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
print(len(cities))
# Out:
# 768

# %%
#Perform an API call with the OpenWeatherMap.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

import time 
from datetime import datetime

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    
    city_url = url + "&q="+ city.replace(" ","+")
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

    except:
        print("City not found. Skipping...")
        pass
    
        
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | matara
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | meadow lake
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | karakol
# Processing Record 13 of Set 1 | san cristobal
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | northam
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | shepsi
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | kigoma
# Processing Record 23 of Set 1 | teneguiban
# City not found. Skipping...
# Processing Record 24 of Set 1 | greaca
# Processing Record 25 of Set 1 | puerto madero
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | broken hill
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | verkhnyaya inta
# Processing Record 32 of Set 1 | sindand
# City not found. Skipping...
# Processing Record 33 of Set 1 | lahat
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | tiznit
# Processing Record 36 of Set 1 | dargaville
# Processing Record 37 of Set 1 | qaqortoq
# Processing Record 38 of Set 1 | lircay
# Processing Record 39 of Set 1 | katsuura
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | bandarbeyla
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | ndele
# Processing Record 49 of Set 1 | komsomolskiy
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | gilgit
# Processing Record 2 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | sambava
# Processing Record 5 of Set 2 | martapura
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | kazachinskoye
# Processing Record 13 of Set 2 | koboko
# Processing Record 14 of Set 2 | meulaboh
# Processing Record 15 of Set 2 | marawi
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | bilma
# Processing Record 20 of Set 2 | aksu
# Processing Record 21 of Set 2 | gagra
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | filingue
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | leningradskiy
# Processing Record 27 of Set 2 | benjamin constant
# Processing Record 28 of Set 2 | margate
# Processing Record 29 of Set 2 | labuhan
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | krasnoselkup
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | srikakulam
# Processing Record 34 of Set 2 | antofagasta
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | dharchula
# Processing Record 41 of Set 2 | marsh harbour
# Processing Record 42 of Set 2 | padilla
# Processing Record 43 of Set 2 | babynino
# Processing Record 44 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 2 | santo domingo suchitepequez
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | erenhot
# Processing Record 48 of Set 2 | huarmey
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | beira
# Processing Record 1 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | springbok
# Processing Record 4 of Set 3 | nueve de julio
# Processing Record 5 of Set 3 | tari
# Processing Record 6 of Set 3 | tuljapur
# Processing Record 7 of Set 3 | shuyskoye
# Processing Record 8 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 3 | ambon
# Processing Record 10 of Set 3 | yar-sale
# Processing Record 11 of Set 3 | hakodate
# Processing Record 12 of Set 3 | taltal
# Processing Record 13 of Set 3 | mala
# Processing Record 14 of Set 3 | acapulco
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | tucuman
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | opole lubelskie
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | mashhad
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | horsham
# Processing Record 23 of Set 3 | alta floresta
# Processing Record 24 of Set 3 | muzhi
# Processing Record 25 of Set 3 | san ramon
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | nadym
# Processing Record 30 of Set 3 | vyshkov
# Processing Record 31 of Set 3 | harper
# Processing Record 32 of Set 3 | kimbe
# Processing Record 33 of Set 3 | tasiilaq
# Processing Record 34 of Set 3 | palmer
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | tepla
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | iberia
# Processing Record 39 of Set 3 | paamiut
# Processing Record 40 of Set 3 | dumai
# Processing Record 41 of Set 3 | poum
# Processing Record 42 of Set 3 | shingu
# Processing Record 43 of Set 3 | teguldet
# Processing Record 44 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 3 | chinsali
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | wattens
# Processing Record 49 of Set 3 | pyshma
# Processing Record 50 of Set 3 | elat
# Processing Record 1 of Set 4 | dali
# Processing Record 2 of Set 4 | dabat
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | yerbogachen
# Processing Record 5 of Set 4 | olafsvik
# Processing Record 6 of Set 4 | pevek
# Processing Record 7 of Set 4 | navalmoral de la mata
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | mana
# Processing Record 10 of Set 4 | paulesti
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | klaksvik
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | tessalit
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | dong hoi
# Processing Record 19 of Set 4 | cam ranh
# Processing Record 20 of Set 4 | pandan
# Processing Record 21 of Set 4 | carnarvon
# Processing Record 22 of Set 4 | richards bay
# Processing Record 23 of Set 4 | adamas
# Processing Record 24 of Set 4 | aanekoski
# Processing Record 25 of Set 4 | slavgorod
# Processing Record 26 of Set 4 | isangel
# Processing Record 27 of Set 4 | juneau
# Processing Record 28 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 4 | el alto
# Processing Record 30 of Set 4 | gat
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | saint anthony
# Processing Record 33 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | holme
# Processing Record 36 of Set 4 | nantucket
# Processing Record 37 of Set 4 | ouesso
# Processing Record 38 of Set 4 | beibei
# Processing Record 39 of Set 4 | jamui
# Processing Record 40 of Set 4 | verkhoyansk
# Processing Record 41 of Set 4 | torit
# Processing Record 42 of Set 4 | chapais
# Processing Record 43 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 44 of Set 4 | faya
# Processing Record 45 of Set 4 | itarema
# Processing Record 46 of Set 4 | nea stira
# Processing Record 47 of Set 4 | itoman
# Processing Record 48 of Set 4 | nishihara
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 50 of Set 4 | saint-joseph
# Processing Record 1 of Set 5 | mount gambier
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | kallifitos
# Processing Record 4 of Set 5 | tuatapere
# Processing Record 5 of Set 5 | jieshi
# Processing Record 6 of Set 5 | kikwit
# Processing Record 7 of Set 5 | carballo
# Processing Record 8 of Set 5 | diego de almagro
# Processing Record 9 of Set 5 | wellington
# Processing Record 10 of Set 5 | imuris
# Processing Record 11 of Set 5 | arraial do cabo
# Processing Record 12 of Set 5 | tahe
# Processing Record 13 of Set 5 | hobyo
# Processing Record 14 of Set 5 | lata
# Processing Record 15 of Set 5 | pavino
# Processing Record 16 of Set 5 | treinta y tres
# Processing Record 17 of Set 5 | port macquarie
# Processing Record 18 of Set 5 | quthing
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | aksarka
# Processing Record 21 of Set 5 | nhulunbuy
# Processing Record 22 of Set 5 | turbat
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | monrovia
# Processing Record 25 of Set 5 | itaituba
# Processing Record 26 of Set 5 | susehri
# Processing Record 27 of Set 5 | cabo san lucas
# Processing Record 28 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 29 of Set 5 | esperance
# Processing Record 30 of Set 5 | komatipoort
# Processing Record 31 of Set 5 | talnakh
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | gumushane
# City not found. Skipping...
# Processing Record 34 of Set 5 | sao gabriel da cachoeira
# Processing Record 35 of Set 5 | arlington
# Processing Record 36 of Set 5 | buerarema
# Processing Record 37 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 5 | antalaha
# Processing Record 39 of Set 5 | diffa
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | comodoro rivadavia
# Processing Record 42 of Set 5 | bundaberg
# Processing Record 43 of Set 5 | matay
# Processing Record 44 of Set 5 | pompeia
# Processing Record 45 of Set 5 | aguimes
# Processing Record 46 of Set 5 | canto do buriti
# Processing Record 47 of Set 5 | auriflama
# Processing Record 48 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 5 | bucak
# Processing Record 50 of Set 5 | champerico
# Processing Record 1 of Set 6 | cienfuegos
# Processing Record 2 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 6 | lasa
# Processing Record 4 of Set 6 | flinders
# Processing Record 5 of Set 6 | sonoita
# Processing Record 6 of Set 6 | cockburn town
# Processing Record 7 of Set 6 | hovd
# Processing Record 8 of Set 6 | jablah
# Processing Record 9 of Set 6 | yairipok
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | gamba
# Processing Record 14 of Set 6 | quatre cocos
# Processing Record 15 of Set 6 | bacolod
# Processing Record 16 of Set 6 | douglas
# Processing Record 17 of Set 6 | havre-saint-pierre
# Processing Record 18 of Set 6 | herat
# Processing Record 19 of Set 6 | taman
# Processing Record 20 of Set 6 | kuji
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | omsukchan
# Processing Record 23 of Set 6 | medea
# Processing Record 24 of Set 6 | ucluelet
# Processing Record 25 of Set 6 | trofors
# Processing Record 26 of Set 6 | belmonte
# Processing Record 27 of Set 6 | inverell
# Processing Record 28 of Set 6 | half moon bay
# Processing Record 29 of Set 6 | amahai
# Processing Record 30 of Set 6 | det udom
# Processing Record 31 of Set 6 | waipawa
# Processing Record 32 of Set 6 | byron bay
# Processing Record 33 of Set 6 | haines junction
# Processing Record 34 of Set 6 | horki
# Processing Record 35 of Set 6 | nizhniy tsasuchey
# Processing Record 36 of Set 6 | coruripe
# Processing Record 37 of Set 6 | joetsu
# Processing Record 38 of Set 6 | sturgeon bay
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | pingliang
# Processing Record 41 of Set 6 | kichera
# Processing Record 42 of Set 6 | roald
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | belgrade
# Processing Record 45 of Set 6 | cairns
# Processing Record 46 of Set 6 | baiyin
# Processing Record 47 of Set 6 | tukrah
# Processing Record 48 of Set 6 | fez
# Processing Record 49 of Set 6 | lavrentiya
# Processing Record 50 of Set 6 | portland
# Processing Record 1 of Set 7 | kirovskiy
# Processing Record 2 of Set 7 | strelka
# Processing Record 3 of Set 7 | manokwari
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | santa cruz de la palma
# Processing Record 7 of Set 7 | beawar
# Processing Record 8 of Set 7 | rolla
# Processing Record 9 of Set 7 | vila do maio
# Processing Record 10 of Set 7 | pachperwa
# Processing Record 11 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 7 | porto seguro
# Processing Record 13 of Set 7 | viransehir
# Processing Record 14 of Set 7 | garden city
# Processing Record 15 of Set 7 | grootfontein
# Processing Record 16 of Set 7 | hasaki
# Processing Record 17 of Set 7 | saedinenie
# Processing Record 18 of Set 7 | soe
# Processing Record 19 of Set 7 | mapiripan
# Processing Record 20 of Set 7 | east london
# Processing Record 21 of Set 7 | porto santo
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | nuuk
# Processing Record 26 of Set 7 | vao
# Processing Record 27 of Set 7 | taikang
# Processing Record 28 of Set 7 | copiapo
# Processing Record 29 of Set 7 | mildura
# Processing Record 30 of Set 7 | vestmannaeyjar
# Processing Record 31 of Set 7 | kirakira
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | tura
# Processing Record 34 of Set 7 | port-gentil
# Processing Record 35 of Set 7 | san quintin
# Processing Record 36 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 7 | katherine
# Processing Record 38 of Set 7 | baykit
# Processing Record 39 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 7 | tokur
# Processing Record 41 of Set 7 | georgetown
# Processing Record 42 of Set 7 | athmallik
# Processing Record 43 of Set 7 | praia
# Processing Record 44 of Set 7 | codrington
# Processing Record 45 of Set 7 | cherskiy
# Processing Record 46 of Set 7 | tawang
# Processing Record 47 of Set 7 | pervomayskiy
# Processing Record 48 of Set 7 | labrea
# Processing Record 49 of Set 7 | gimli
# Processing Record 50 of Set 7 | iskateley
# Processing Record 1 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 2 of Set 8 | rocha
# Processing Record 3 of Set 8 | meridian
# Processing Record 4 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 5 of Set 8 | kamaishi
# Processing Record 6 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 8 | ostrovnoy
# Processing Record 9 of Set 8 | bud
# Processing Record 10 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 8 | pionki
# Processing Record 12 of Set 8 | taylorville
# Processing Record 13 of Set 8 | sao jose da coroa grande
# Processing Record 14 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | plettenberg bay
# Processing Record 17 of Set 8 | pangnirtung
# Processing Record 18 of Set 8 | karamken
# City not found. Skipping...
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | trelew
# Processing Record 21 of Set 8 | kaduna
# Processing Record 22 of Set 8 | fort nelson
# Processing Record 23 of Set 8 | ryzdvyanyy
# Processing Record 24 of Set 8 | valdivia
# Processing Record 25 of Set 8 | te anau
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | tashtagol
# Processing Record 28 of Set 8 | razole
# Processing Record 29 of Set 8 | gotsu
# Processing Record 30 of Set 8 | aleksandrov gay
# Processing Record 31 of Set 8 | southbridge
# Processing Record 32 of Set 8 | namibe
# Processing Record 33 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 8 | popondetta
# Processing Record 35 of Set 8 | igarka
# Processing Record 36 of Set 8 | clyde river
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | talcahuano
# Processing Record 39 of Set 8 | ossora
# Processing Record 40 of Set 8 | mackenzie
# Processing Record 41 of Set 8 | tshikapa
# Processing Record 42 of Set 8 | garissa
# Processing Record 43 of Set 8 | pisco
# Processing Record 44 of Set 8 | adrar
# Processing Record 45 of Set 8 | linshu
# City not found. Skipping...
# Processing Record 46 of Set 8 | taoudenni
# Processing Record 47 of Set 8 | jalu
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | owando
# Processing Record 50 of Set 8 | port moresby
# Processing Record 1 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 9 | sola
# Processing Record 3 of Set 9 | coahuayana
# Processing Record 4 of Set 9 | maragogi
# Processing Record 5 of Set 9 | egvekinot
# Processing Record 6 of Set 9 | thompson
# Processing Record 7 of Set 9 | waddan
# Processing Record 8 of Set 9 | laguna
# Processing Record 9 of Set 9 | great yarmouth
# Processing Record 10 of Set 9 | nanortalik
# Processing Record 11 of Set 9 | bonavista
# Processing Record 12 of Set 9 | isabela
# Processing Record 13 of Set 9 | kieta
# Processing Record 14 of Set 9 | vila
# Processing Record 15 of Set 9 | kavant
# City not found. Skipping...
# Processing Record 16 of Set 9 | gizo
# Processing Record 17 of Set 9 | bunia
# Processing Record 18 of Set 9 | pozo colorado
# Processing Record 19 of Set 9 | basoda
# Processing Record 20 of Set 9 | vanimo
# Processing Record 21 of Set 9 | newport
# Processing Record 22 of Set 9 | ketchikan
# Processing Record 23 of Set 9 | manavalakurichi
# Processing Record 24 of Set 9 | geraldton
# Processing Record 25 of Set 9 | sitka
# Processing Record 26 of Set 9 | rajamahendri
# City not found. Skipping...
# Processing Record 27 of Set 9 | ibra
# Processing Record 28 of Set 9 | turukhansk
# Processing Record 29 of Set 9 | tacuarembo
# Processing Record 30 of Set 9 | chernyshevskiy
# Processing Record 31 of Set 9 | port hedland
# Processing Record 32 of Set 9 | benguela
# Processing Record 33 of Set 9 | asau
# Processing Record 34 of Set 9 | sembakung
# Processing Record 35 of Set 9 | gaoual
# Processing Record 36 of Set 9 | bolshoy lug
# Processing Record 37 of Set 9 | rosetta
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | birao
# Processing Record 40 of Set 9 | the valley
# Processing Record 41 of Set 9 | wlingi
# Processing Record 42 of Set 9 | saint george
# Processing Record 43 of Set 9 | bayir
# Processing Record 44 of Set 9 | iranshahr
# Processing Record 45 of Set 9 | redlands
# Processing Record 46 of Set 9 | mogzon
# Processing Record 47 of Set 9 | cabinda
# Processing Record 48 of Set 9 | chulym
# Processing Record 49 of Set 9 | palora
# Processing Record 50 of Set 9 | ayaviri
# Processing Record 1 of Set 10 | iracoubo
# Processing Record 2 of Set 10 | bereda
# Processing Record 3 of Set 10 | necochea
# Processing Record 4 of Set 10 | pokaran
# Processing Record 5 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 6 of Set 10 | teahupoo
# Processing Record 7 of Set 10 | constitucion
# Processing Record 8 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 10 | pabianice
# Processing Record 10 of Set 10 | la ronge
# Processing Record 11 of Set 10 | esso
# Processing Record 12 of Set 10 | santa marta
# Processing Record 13 of Set 10 | kalmunai
# Processing Record 14 of Set 10 | jasper
# Processing Record 15 of Set 10 | gaborone
# Processing Record 16 of Set 10 | kolondieba
# Processing Record 17 of Set 10 | pyapon
# Processing Record 18 of Set 10 | alofi
# Processing Record 19 of Set 10 | hamilton
# Processing Record 20 of Set 10 | gorom-gorom
# Processing Record 21 of Set 10 | dalinghe
# City not found. Skipping...
# Processing Record 22 of Set 10 | dhali
# Processing Record 23 of Set 10 | yenagoa
# Processing Record 24 of Set 10 | tazovskiy
# Processing Record 25 of Set 10 | sao joao da barra
# Processing Record 26 of Set 10 | acajutla
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | barcelos
# Processing Record 29 of Set 10 | zhezkazgan
# Processing Record 30 of Set 10 | kutum
# Processing Record 31 of Set 10 | ust-nera
# Processing Record 32 of Set 10 | teguise
# Processing Record 33 of Set 10 | hofn
# Processing Record 34 of Set 10 | balikpapan
# Processing Record 35 of Set 10 | santa vitoria do palmar
# Processing Record 36 of Set 10 | college
# Processing Record 37 of Set 10 | santa isabel do rio negro
# Processing Record 38 of Set 10 | nabire
# Processing Record 39 of Set 10 | robertsport
# Processing Record 40 of Set 10 | xiongzhou
# Processing Record 41 of Set 10 | muli
# Processing Record 42 of Set 10 | vila franca do campo
# Processing Record 43 of Set 10 | kangaatsiaq
# Processing Record 44 of Set 10 | bilibino
# Processing Record 45 of Set 10 | cao bang
# Processing Record 46 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 47 of Set 10 | topolobampo
# Processing Record 48 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 10 | port blair
# Processing Record 50 of Set 10 | lisakovsk
# Processing Record 1 of Set 11 | prince rupert
# Processing Record 2 of Set 11 | berlevag
# Processing Record 3 of Set 11 | boyolangu
# Processing Record 4 of Set 11 | morondava
# Processing Record 5 of Set 11 | burica
# City not found. Skipping...
# Processing Record 6 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 11 | prince george
# Processing Record 8 of Set 11 | grindavik
# Processing Record 9 of Set 11 | yerofey pavlovich
# Processing Record 10 of Set 11 | lianzhou
# Processing Record 11 of Set 11 | xining
# Processing Record 12 of Set 11 | kyotera
# Processing Record 13 of Set 11 | makat
# Processing Record 14 of Set 11 | katobu
# Processing Record 15 of Set 11 | turan
# Processing Record 16 of Set 11 | verkh-usugli
# Processing Record 17 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 11 | chumikan
# Processing Record 19 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 11 | damghan
# Processing Record 21 of Set 11 | sorong
# Processing Record 22 of Set 11 | beitbridge
# Processing Record 23 of Set 11 | koregaon
# Processing Record 24 of Set 11 | avera
# Processing Record 25 of Set 11 | haukipudas
# Processing Record 26 of Set 11 | dunedin
# Processing Record 27 of Set 11 | doka
# Processing Record 28 of Set 11 | totness
# Processing Record 29 of Set 11 | menongue
# Processing Record 30 of Set 11 | itatiba
# Processing Record 31 of Set 11 | tecoanapa
# Processing Record 32 of Set 11 | qandala
# Processing Record 33 of Set 11 | novolvovsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | parksville
# Processing Record 35 of Set 11 | khovu-aksy
# Processing Record 36 of Set 11 | cordoba
# Processing Record 37 of Set 11 | lagoa
# Processing Record 38 of Set 11 | awjilah
# Processing Record 39 of Set 11 | karpogory
# Processing Record 40 of Set 11 | krasnokholm
# Processing Record 41 of Set 11 | dingle
# Processing Record 42 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 11 | banda aceh
# Processing Record 44 of Set 11 | biltine
# Processing Record 45 of Set 11 | arroyo
# Processing Record 46 of Set 11 | kurumkan
# Processing Record 47 of Set 11 | khasan
# Processing Record 48 of Set 11 | nyimba
# Processing Record 49 of Set 11 | mahibadhoo
# Processing Record 50 of Set 11 | basoko
# Processing Record 1 of Set 12 | seoul
# Processing Record 2 of Set 12 | aldan
# Processing Record 3 of Set 12 | belaya gora
# Processing Record 4 of Set 12 | road town
# Processing Record 5 of Set 12 | awbari
# Processing Record 6 of Set 12 | pampa
# Processing Record 7 of Set 12 | zvecka
# Processing Record 8 of Set 12 | bac lieu
# Processing Record 9 of Set 12 | voloshka
# Processing Record 10 of Set 12 | gorizia
# Processing Record 11 of Set 12 | marshfield
# Processing Record 12 of Set 12 | oksfjord
# Processing Record 13 of Set 12 | urucara
# Processing Record 14 of Set 12 | morgaushi
# Processing Record 15 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 12 | vilhena
# Processing Record 17 of Set 12 | kenai
# Processing Record 18 of Set 12 | alice springs
# Processing Record 19 of Set 12 | molteno
# Processing Record 20 of Set 12 | nyurba
# Processing Record 21 of Set 12 | kalengwa
# Processing Record 22 of Set 12 | grafton
# Processing Record 23 of Set 12 | olinda
# Processing Record 24 of Set 12 | aklavik
# Processing Record 25 of Set 12 | erzin
# Processing Record 26 of Set 12 | manat
# Processing Record 27 of Set 12 | samarai
# Processing Record 28 of Set 12 | adre
# Processing Record 29 of Set 12 | lyuban
# Processing Record 30 of Set 12 | pryazha
# Processing Record 31 of Set 12 | atar
# Processing Record 32 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | hirara
# Processing Record 35 of Set 12 | kuusamo
# Processing Record 36 of Set 12 | atocha
# Processing Record 37 of Set 12 | biak
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | zurrieq
# Processing Record 40 of Set 12 | charters towers
# Processing Record 41 of Set 12 | bathurst
# Processing Record 42 of Set 12 | beisfjord
# Processing Record 43 of Set 12 | husavik
# Processing Record 44 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 12 | nemuro
# Processing Record 46 of Set 12 | benjamin hill
# Processing Record 47 of Set 12 | plouzane
# Processing Record 48 of Set 12 | asyut
# Processing Record 49 of Set 12 | miandrivazo
# Processing Record 50 of Set 12 | lisala
# Processing Record 1 of Set 13 | emba
# Processing Record 2 of Set 13 | sabaudia
# Processing Record 3 of Set 13 | mugumu
# Processing Record 4 of Set 13 | kemijarvi
# Processing Record 5 of Set 13 | akkudah
# City not found. Skipping...
# Processing Record 6 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 13 | saint-augustin
# Processing Record 8 of Set 13 | dawei
# Processing Record 9 of Set 13 | chuy
# Processing Record 10 of Set 13 | gobabis
# Processing Record 11 of Set 13 | nome
# Processing Record 12 of Set 13 | gorin
# Processing Record 13 of Set 13 | oranjemund
# Processing Record 14 of Set 13 | zadar
# Processing Record 15 of Set 13 | caxito
# Processing Record 16 of Set 13 | riyadh
# Processing Record 17 of Set 13 | seymchan
# Processing Record 18 of Set 13 | buzmeyin
# Processing Record 19 of Set 13 | yarada
# Processing Record 20 of Set 13 | vanderhoof
# Processing Record 21 of Set 13 | nong khai
# Processing Record 22 of Set 13 | merauke
# Processing Record 23 of Set 13 | rovaniemi
# Processing Record 24 of Set 13 | borama
# City not found. Skipping...
# Processing Record 25 of Set 13 | wuda
# Processing Record 26 of Set 13 | brae
# Processing Record 27 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 13 | jega
# Processing Record 29 of Set 13 | luena
# Processing Record 30 of Set 13 | cururupu
# Processing Record 31 of Set 13 | moyobamba
# Processing Record 32 of Set 13 | egana
# Processing Record 33 of Set 13 | phumi samraong
# City not found. Skipping...
# Processing Record 34 of Set 13 | barahona
# Processing Record 35 of Set 13 | conway
# Processing Record 36 of Set 13 | muswellbrook
# Processing Record 37 of Set 13 | san andres
# Processing Record 38 of Set 13 | lithakia
# Processing Record 39 of Set 13 | chifeng
# Processing Record 40 of Set 13 | pinos puente
# Processing Record 41 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 42 of Set 13 | terrace
# Processing Record 43 of Set 13 | comarapa
# Processing Record 44 of Set 13 | korla
# Processing Record 45 of Set 13 | burgos
# Processing Record 46 of Set 13 | nelson bay
# Processing Record 47 of Set 13 | yumen
# Processing Record 48 of Set 13 | jiuquan
# Processing Record 49 of Set 13 | lieto
# Processing Record 50 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 1 of Set 14 | alekseyevka
# Processing Record 2 of Set 14 | mbandaka
# Processing Record 3 of Set 14 | ikryanoye
# Processing Record 4 of Set 14 | anahuac
# Processing Record 5 of Set 14 | plainview
# Processing Record 6 of Set 14 | yulara
# Processing Record 7 of Set 14 | kayes
# Processing Record 8 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 14 | bondoukou
# Processing Record 10 of Set 14 | saint-pierre
# Processing Record 11 of Set 14 | santa clarita
# Processing Record 12 of Set 14 | whithorn
# Processing Record 13 of Set 14 | raga
# Processing Record 14 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 14 | high level
# Processing Record 16 of Set 14 | oussouye
# Processing Record 17 of Set 14 | broome
# Processing Record 18 of Set 14 | parsons
# Processing Record 19 of Set 14 | qidong
# Processing Record 20 of Set 14 | pestovo
# Processing Record 21 of Set 14 | scarborough
# Processing Record 22 of Set 14 | irbit
# Processing Record 23 of Set 14 | moussoro
# Processing Record 24 of Set 14 | pokhara
# Processing Record 25 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 14 | lapeer
# Processing Record 27 of Set 14 | kattivakkam
# Processing Record 28 of Set 14 | zambezi
# Processing Record 29 of Set 14 | ust-kulom
# Processing Record 30 of Set 14 | eyl
# Processing Record 31 of Set 14 | grand-lahou
# Processing Record 32 of Set 14 | strezhevoy
# Processing Record 33 of Set 14 | carinhanha
# Processing Record 34 of Set 14 | makakilo city
# Processing Record 35 of Set 14 | san juan
# Processing Record 36 of Set 14 | goya
# Processing Record 37 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 39 of Set 14 | palmares do sul
# Processing Record 40 of Set 14 | marsa matruh
# Processing Record 41 of Set 14 | opuwo
# Processing Record 42 of Set 14 | yurino
# Processing Record 43 of Set 14 | vaitape
# Processing Record 44 of Set 14 | palmas
# Processing Record 45 of Set 14 | ukiah
# Processing Record 46 of Set 14 | chernyy yar
# Processing Record 47 of Set 14 | ormara
# Processing Record 48 of Set 14 | peterhead
# Processing Record 49 of Set 14 | melfi
# Processing Record 50 of Set 14 | maniitsoq
# Processing Record 1 of Set 15 | buckeye
# Processing Record 2 of Set 15 | xichang
# Processing Record 3 of Set 15 | mariel
# Processing Record 4 of Set 15 | latung
# Processing Record 5 of Set 15 | viedma
# Processing Record 6 of Set 15 | mount isa
# Processing Record 7 of Set 15 | octeville
# Processing Record 8 of Set 15 | angola
# Processing Record 9 of Set 15 | alyangula
# Processing Record 10 of Set 15 | fallon
# Processing Record 11 of Set 15 | stokmarknes
# Processing Record 12 of Set 15 | tommot
# Processing Record 13 of Set 15 | coihaique
# Processing Record 14 of Set 15 | tigil
# Processing Record 15 of Set 15 | tautira
# Processing Record 16 of Set 15 | pangody
# Processing Record 17 of Set 15 | sistranda
# Processing Record 18 of Set 15 | san rafael del sur
# Processing Record 19 of Set 15 | yoichi
# Processing Record 20 of Set 15 | chicama
# Processing Record 21 of Set 15 | serang
# Processing Record 22 of Set 15 | bay city
# Processing Record 23 of Set 15 | zaokskiy
# Processing Record 24 of Set 15 | unguia
# Processing Record 25 of Set 15 | aitape
# Processing Record 26 of Set 15 | iguape
# Processing Record 27 of Set 15 | calabozo
# Processing Record 28 of Set 15 | fare
# Processing Record 29 of Set 15 | pacifica
# Processing Record 30 of Set 15 | imbituba
# Processing Record 31 of Set 15 | abha
# Processing Record 32 of Set 15 | abu samrah
# Processing Record 33 of Set 15 | abapo
# Processing Record 34 of Set 15 | syracuse
# Processing Record 35 of Set 15 | shahrud
# Processing Record 36 of Set 15 | buraydah
# Processing Record 37 of Set 15 | owosso
# Processing Record 38 of Set 15 | hami
# Processing Record 39 of Set 15 | clarence town
# Processing Record 40 of Set 15 | zyryanovsk
# Processing Record 41 of Set 15 | creel
# Processing Record 42 of Set 15 | mocuba
# Processing Record 43 of Set 15 | tevaitoa
# Processing Record 44 of Set 15 | ferme-neuve
# Processing Record 45 of Set 15 | sao felix do xingu
# Processing Record 46 of Set 15 | roebourne
# Processing Record 47 of Set 15 | humberto de campos
# Processing Record 48 of Set 15 | marzuq
# Processing Record 49 of Set 15 | gondar
# Processing Record 50 of Set 15 | balabac
# Processing Record 1 of Set 16 | voi
# Processing Record 2 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 16 | formosa
# Processing Record 4 of Set 16 | pottsville
# Processing Record 5 of Set 16 | qax
# Processing Record 6 of Set 16 | mocajuba
# Processing Record 7 of Set 16 | piacabucu
# Processing Record 8 of Set 16 | fomboni
# Processing Record 9 of Set 16 | kharp
# Processing Record 10 of Set 16 | coquimbo
# Processing Record 11 of Set 16 | korem
# Processing Record 12 of Set 16 | sidi bu zayd
# City not found. Skipping...
# Processing Record 13 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 16 | pidsandawan
# Processing Record 15 of Set 16 | tunduma
# Processing Record 16 of Set 16 | inirida
# Processing Record 17 of Set 16 | ponta delgada
# Processing Record 18 of Set 16 | hit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Matara      LK   5.9485   80.5353     74.68        84          90
# 1           Albany      US  42.6001  -73.9662     27.68        60          71
# 2           Barrow      US  71.2906 -156.7887    -25.58        68           0
# 3           Avarua      CK -21.2078 -159.7750     82.45        78          20
# 4         Bengkulu      ID  -3.8004  102.2655     75.92        87         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 692    Pidsandawan      PH   6.9322  124.5908     72.63        87          69
# 693        Tunduma      TZ  -9.3000   32.7667     57.33        93         100
# 694        Inirida      CO   3.8653  -67.9239     83.52        73         100
# 695  Ponta Delgada      PT  37.7333  -25.6667     61.50        88          20
# 696            Hit      IQ  33.6416   42.8251     52.52        51          49
#
#      Wind Speed Current Description
# 0          2.86     overcast clouds
# 1          1.99       broken clouds
# 2         11.50           clear sky
# 3         11.50          few clouds
# 4          9.80     overcast clouds
# ..          ...                 ...
# 692        0.31       broken clouds
# 693        1.97     overcast clouds
# 694        3.53     overcast clouds
# 695       12.66          few clouds
# 696        3.58    scattered clouds
#
# [697 rows x 9 columns]

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_id')
